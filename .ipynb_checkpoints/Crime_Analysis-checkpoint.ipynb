# %%
import pandas as pd
import requests
import json
import numpy as np
from uszipcode import SearchEngine
import matplotlib.pyplot as plt
from pandas.tools.plotting import table

# %%
arrest_file = "LA Arrest Data 2018.csv"

# %%
crimedf = pd.read_csv(arrest_file, encoding='utf8')

# %%
# Remove arrest location without lat,lng
crimedf = crimedf[crimedf.Lat != 0]

# %% [raw]
# #Using USZipCode to loop through crime data.
#     #reversegeo lookup of incident cooridnates to find zip code and population
#     #Already ran this once which is why this is quoted out
# '''# Loop through rows using USzip to get new data
# search = SearchEngine(simple_zipcode=True)
# for index,row in crimedf.iterrows():
#     query = search.by_coordinates(row['Lat'], row['Lng'], radius=30, returns=1)
#     crimedf.loc[index,"Zip Code"] = query[0].zipcode
#     crimedf.loc[index,"Population"] = query[0].population
#     crimedf.loc[index,"City"] = query[0].major_city
#     crimedf.loc[index,"County"] = query[0].county'''

# %%
#ran this once 
#crimedf.to_csv('LA Arrest Data 2018_Clean.csv')

# %%
New_arrest_file = ('LA Arrest Data 2018_Clean.csv')

# %%
crimedf_clean = pd.read_csv(New_arrest_file, encoding='utf8')

# %%
#Create new table of zip,city, zip Population for later merge
City_info_Summary_df = crimedf_clean[['Zip Code','City','Population','County']].drop_duplicates()

# %%
crimedf_clean.head()
# Out:
#    Unnamed: 0  Report ID Arrest Date    Time  Area ID  Area Name  \
# 0           0    5192940    1/1/2018  1625.0       11  Northeast
# 1           1    5192650    1/1/2018  1400.0       18  Southeast
# 2           2    5192692    1/1/2018   845.0        7   Wilshire
# 3           3    5192949    1/1/2018  1810.0        3  Southwest
# 4           4    5192436    1/1/2018   120.0       13     Newton
#
#    Reporting District  Age Sex Code Descent Code         ...          \
# 0                1123   27        M            H         ...
# 1                1822   25        M            H         ...
# 2                 702   37        M            H         ...
# 3                 332   57        M            B         ...
# 4                1362   27        M            H         ...
#
#                         Charge Description  \
# 0  TRANSPORT/SELL/ETC CONTROLLED SUBSTANCE
# 1                    BURGLARY FROM VEHICLE
# 2               DUI ALCOHOL/DRUGS W/INJURY
# 3                                 BURGLARY
# 4               VIOLATION OF PAROLE:FELONY
#
#                                    Address Cross Street              Location  \
# 0  3900    BRUNSWICK                    AV          NaN    (34.123, -118.264)
# 1          CENTURY                      BL     BROADWAY  (33.9456, -118.2781)
# 2                                  MELROSE      GARDNER  (34.0837, -118.3532)
# 3  3000    POTOMAC                      AV          NaN  (34.0276, -118.3439)
# 4  5100    AVALON                       BL          NaN  (33.9981, -118.2697)
#
#        Lat       Lng Zip Code Population         City              County
# 0  34.1230 -118.2640    90039    28514.0  Los Angeles  Los Angeles County
# 1  33.9456 -118.2781    90044    89779.0  Los Angeles  Los Angeles County
# 2  34.0837 -118.3532    90036    36865.0  Los Angeles  Los Angeles County
# 3  34.0276 -118.3439    90016    47596.0  Los Angeles  Los Angeles County
# 4  33.9981 -118.2697    90011   103892.0  Los Angeles  Los Angeles County
#
# [5 rows x 24 columns]

# %%
City_info_Summary_df.to_csv('Zip Info Summary.csv')
City_info_Summary_df.head()
# Out:
#    Zip Code         City  Population              County
# 0     90039  Los Angeles     28514.0  Los Angeles County
# 1     90044  Los Angeles     89779.0  Los Angeles County
# 2     90036  Los Angeles     36865.0  Los Angeles County
# 3     90016  Los Angeles     47596.0  Los Angeles County
# 4     90011  Los Angeles    103892.0  Los Angeles County

# %%
#Create Incident summary dataframe
Incidents_by_Zip = crimedf_clean.groupby('Zip Code').count()['Sex Code']
Incidents_by_Zip_clean = pd.DataFrame({'Zip Code':Incidents_by_Zip.index, '# of Incidents':Incidents_by_Zip.values})
Incidents_by_Zip_clean.head()
# Out:
#    Zip Code  # of Incidents
# 0     90001             395
# 1     90002             837
# 2     90003            2953
# 3     90004            1173
# 4     90005             940

# %%
#Create Dispensary Count summary dataframe
Dispendarydf = pd.read_csv('marijuana_dispensaries_w_coords.csv', encoding='utf8')
Dispendarydf_clean = Dispendarydf[Dispendarydf.County =='LOS ANGELES'] #filter DF for only those in LA County
Dispendarydf_clean.head()
# Out:
#     Unnamed: 0       License Number                           License Type  \
# 3            3  C10-18-0000288-TEMP  Cannabis - Retailer Temporary License
# 6            6  C10-18-0000291-TEMP  Cannabis - Retailer Temporary License
# 7            7  C10-18-0000292-TEMP  Cannabis - Retailer Temporary License
# 13          13  C10-18-0000278-TEMP  Cannabis - Retailer Temporary License
# 14          14  C10-18-0000279-TEMP  Cannabis - Retailer Temporary License
#
#       Business Owner                       Business Contact Information  \
# 3       Basil Bailey  ORIGINAL BALBOA CAREGIVERS : Email- balboacare...
# 6       Maria Colvin  Hollywood Holistic Healers, Inc. : Email- holl...
# 7     David Barakett  THE AIRPORT COLLECTIVE, INC. : Email- longbeac...
# 13        Shaun Lang  Strain Balboa Caregivers, Inc. : Email- nuashx...
# 14  Robert Rosenheck  REDWOOD RETAIL, LLC  : Lord Jones : Email- mon...
#
#            Business Structure                 Premise Address  CA  Zip Code  \
# 3                 Corporation       9419 MASON AVE CHATSWORTH  CA     91311
# 6                 Corporation  8210 W SUNSET BLVD LOS ANGELES  CA     90046
# 7                 Corporation      3411 ANAHEIM ST LONG BEACH  CA     90804
# 13                Corporation  21627 DEVONSHIRE ST CHATSWORTH  CA     91311
# 14  Limited Liability Company    8300 SUNSET BLVD LOS ANGELES  CA     90069
#
#    County_with leading space       County  Status  Issue Date Expiration Date  \
# 3               LOS ANGELES   LOS ANGELES  Active  12/31/2018       7/29/2019
# 6                LOS ANGELES  LOS ANGELES  Active  12/31/2018       7/29/2019
# 7               LOS ANGELES   LOS ANGELES  Active  12/31/2018       7/29/2019
# 13              LOS ANGELES   LOS ANGELES  Active  12/29/2018       7/27/2019
# 14              LOS ANGELES   LOS ANGELES  Active  12/29/2018       7/27/2019
#
#                    Activities Adult-Use/Medicinal   Latitude   Longitude
# 3   N/A for this license type                BOTH  34.241268 -118.580710
# 6   N/A for this license type                BOTH  34.097766 -118.367984
# 7   N/A for this license type                BOTH  33.783170 -118.152108
# 13  N/A for this license type                BOTH  34.257461 -118.601340
# 14  N/A for this license type           Adult-Use  34.095945 -118.370894

# %%
# Counts # of dispensaries by Zip Code
Dispendary_by_Zip = Dispendarydf_clean.groupby('Zip Code').count()['CA']
Dispendary_by_Zip_Clean = pd.DataFrame({'Zip Code':Dispendary_by_Zip.index, '# of Dispensaries':Dispendary_by_Zip.values})
Dispendary_by_Zip_Clean.to_csv('LA County # of Dispensaries by Zip.csv')

# %%
City_Crime_Final = pd.merge(Incidents_by_Zip_clean,City_info_Summary_df, on='Zip Code',how='left')
City_Crime_Final = pd.merge(City_Crime_Final,Dispendary_by_Zip_Clean, on='Zip Code',how='left').fillna('0')
City_Crime_Final = City_Crime_Final[City_Crime_Final.Population != 0]
City_Crime_Final['Incidents per capita']= (City_Crime_Final['# of Incidents']/City_Crime_Final['Population'])*1000
City_Crime_Final = City_Crime_Final[City_Crime_Final["Incidents per capita"] < 5000]
City_Crime_Final['# of Dispensaries'] = City_Crime_Final['# of Dispensaries'].astype(int)

# %%
City_Crime_Final.to_csv('City_Crime_Final.csv',index=False)

# %%
City_Crime_Final.head()
# Out:
#    Zip Code  # of Incidents         City  Population              County  \
# 0     90001             395  Los Angeles     57110.0  Los Angeles County
# 1     90002             837  Los Angeles     51223.0  Los Angeles County
# 2     90003            2953  Los Angeles     66266.0  Los Angeles County
# 3     90004            1173  Los Angeles     62180.0  Los Angeles County
# 4     90005             940  Los Angeles     37681.0  Los Angeles County
#
#    # of Dispensaries  Incidents per capita
# 0                  3              6.916477
# 1                  0             16.340316
# 2                  0             44.562823
# 3                  0             18.864587
# 4                  0             24.946259

# %%
City_Crime_Final.head()
# Out:
#    Zip Code  # of Incidents         City  Population              County  \
# 0     90001             395  Los Angeles     57110.0  Los Angeles County
# 1     90002             837  Los Angeles     51223.0  Los Angeles County
# 2     90003            2953  Los Angeles     66266.0  Los Angeles County
# 3     90004            1173  Los Angeles     62180.0  Los Angeles County
# 4     90005             940  Los Angeles     37681.0  Los Angeles County
#
#    # of Dispensaries  Incidents per capita
# 0                  3              6.916477
# 1                  0             16.340316
# 2                  0             44.562823
# 3                  0             18.864587
# 4                  0             24.946259

# %%
def f(row):
    if row['# of Dispensaries'] == 0:
        val = 'No Dispensary'
    else:
        val = 'Has Dispensary'
    return val

# %%
City_Crime_Final['Has Dispensary'] = City_Crime_Final.apply(f, axis=1)
City_Crime_Final.head()
# Out:
#    Zip Code  # of Incidents         City  Population              County  \
# 0     90001             395  Los Angeles     57110.0  Los Angeles County
# 1     90002             837  Los Angeles     51223.0  Los Angeles County
# 2     90003            2953  Los Angeles     66266.0  Los Angeles County
# 3     90004            1173  Los Angeles     62180.0  Los Angeles County
# 4     90005             940  Los Angeles     37681.0  Los Angeles County
#
#    # of Dispensaries  Incidents per capita  Has Dispensary
# 0                  3              6.916477  Has Dispensary
# 1                  0             16.340316   No Dispensary
# 2                  0             44.562823   No Dispensary
# 3                  0             18.864587   No Dispensary
# 4                  0             24.946259   No Dispensary

# %%
Zip_Type_Comparison = City_Crime_Final.groupby('Has Dispensary').mean()
del Zip_Type_Comparison['Zip Code']
del Zip_Type_Comparison['# of Dispensaries']
Zip_Type_Comparison = Zip_Type_Comparison.round(decimals=0)
Zip_Type_Comparison = Zip_Type_Comparison.rename(columns={'# of Incidents':'Avg. # of Incidents',
                                   'Population':'Avg. Population (per zip code)',
                                   'Incidents per capita':'Avg. Incidents (per thousand)'})
Zip_Type_Comparison.reset_index()
# Out:
#    Has Dispensary  Avg. # of Incidents  Avg. Population (per zip code)  \
# 0  Has Dispensary                989.0                         38577.0
# 1   No Dispensary                456.0                         31652.0
#
#    Avg. Incidents (per thousand)
# 0                           41.0
# 1                           69.0

# %%
Zip_Type_Comparison.to_csv('Dispensary_Type_Table.csv')

# %%
plt.bar(['Has Dispensary','Does not have Dispensary'],Zip_Type_Comparison['Avg. Incidents (per thousand)'])
plt.ylabel('Incidents per 1000')
plt.title("Arrest rate by Dispensary Centers")
plt.savefig('Incident_rate_bar')

# %%
Incident_Dispensary_Final = City_Crime_Final.groupby(['# of Dispensaries'])[["Incidents per capita"]].mean()
Incident_Dispensary_Final = Incident_Dispensary_Final.reset_index()
Incident_Dispensary_Final['# of Dispensaries']=Incident_Dispensary_Final['# of Dispensaries'].astype(int)
Incident_Dispensary_Final = Incident_Dispensary_Final[Incident_Dispensary_Final['# of Dispensaries'] <9]

# %%
plt.figure(figsize=[6,5])
plt.scatter(City_Crime_Final['Incidents per capita'],City_Crime_Final['# of Dispensaries'],alpha =.5, linewidth= .5,edgecolors = 'black')
plt.xlim(-5,200)
plt.title('Incident rate vs # of Dispensaries')
plt.ylabel('# of Dispensaries')
plt.xlabel('Rate of Incidents by Population per 1000')

plt.savefig('By Incindent rate_Scatter')

# %%
City_Crime_Final['Incidents per capita'].corr(City_Crime_Final['# of Dispensaries'])
# Out:
# -0.016164173149427568

# %%
City_Crime_Final['# of Dispensaries'].corr(City_Crime_Final['Incidents per capita'])
# Out:
# -0.016164173149427568

# %%
crimedf_clean_2 = pd.merge(crimedf_clean, Dispendary_by_Zip_Clean, on='Zip Code',how='left').fillna('0')
crimedf_clean_2.to_csv('Tableau Data.csv')

# %%
plt.scatter(crimedf_clean_2['Arrest Date'],crimedf_clean_2['# of Dispensaries'],alpha =.5)
plt.title('Incidents in 2018')
plt.ylabel('# of Dispensaries')
plt.xlabel('Arrest Date')
plt.xticks([330,30])
plt.savefig('By Incindent Arrest date and Dispensary')

# %%
crimedf_sample = crimedf_clean_2.sample(2000)
crimedf_sample['Arrest DT'] = pd.to_datetime(crimedf_sample['Arrest Date'])
crimedf_sample['Month'] = crimedf_sample['Arrest DT'].dt.month
plt.scatter(crimedf_sample['Month'],crimedf_sample['# of Dispensaries'],alpha =.5)
# 41221       41226    5320176   5/23/2018  1520       11    Northeast
# 78252       78267    5428678   9/21/2018  1115        7     Wilshire
# 95343       95360  180625015   12/1/2018  2335        6    Hollywood
# 48048       48055  181314142   6/14/2018  1805       13       Newton
# 25766       25768    5272761    4/1/2018  1320       12  77th Street
# 55919       55928  180914137   7/11/2018  1144        9     Van Nuys
# 61898       61908    5381905   7/31/2018  1300        2      Rampart
# 10088       10090    5222645    2/3/2018  1122        6    Hollywood
# 37681       37686    5309542   5/11/2018  2215       12  77th Street
# 72060       72073  180815556   8/31/2018   910        8      West LA
# 97044       97061    5492240   12/9/2018  2330       19      Mission
# 81560       81575  180918562   10/3/2018  2320        9     Van Nuys
# 89947       89962    5469162   11/8/2018  1635        3    Southwest
# 2395         2395    5200130   1/10/2018   455       12  77th Street
# 21512       21514    5259235   3/16/2018   835        7     Wilshire
#
#        Reporting District  Age Sex Code Descent Code  ...    \
# 68039                1265   29        M            B  ...
# 60153                 666   21        M            H  ...
# 35909                1215   20        M            B  ...
# 86624                1657   35        M            O  ...
# 38426                1827   38        M            H  ...
# 91883                 893   21        M            H  ...
# 28250                1203   20        F            B  ...
# 9157                  361   27        M            B  ...
# 62032                 551   39        M            W  ...
# 66716                1998   23        M            H  ...
# 11789                 645   25        M            H  ...
# 67033                 166   49        M            B  ...
# 17928                1258   82        M            H  ...
# 98536                1407   30        F            W  ...
# 37346                 926   29        M            H  ...
# 95801                1494   38        F            B  ...
# 6467                  898   20        F            H  ...
# 61433                 915   34        M            H  ...
# 14049                 201   37        M            H  ...
# 35614                 805   41        F            O  ...
# 22032                 214   25        M            H  ...
# 10110                2035   58        M            H  ...
# 18182                 657   20        M            H  ...
# 41065                 246   35        M            H  ...
# 87424                1502   30        M            O  ...
# 71083                1555   21        M            H  ...
# 15489                 637   48        M            B  ...
# 89119                1245   59        F            B  ...
# 17072                 881   45        M            W  ...
# 31467                1695   41        F            W  ...
# ...                   ...  ...      ...          ...  ...
# 34660                2027   22        M            H  ...
# 73538                1029   18        M            H  ...
# 29653                 143   47        M            B  ...
# 63483                1665   37        M            H  ...
# 48558                 935   20        M            H  ...
# 19672                 152   42        M            W  ...
# 4877                 1494   42        M            H  ...
# 77995                 138   42        M            W  ...
# 19587                 636   36        M            B  ...
# 13122                1183   38        M            W  ...
# 21546                 245   29        M            H  ...
# 98349                 519   14        M            H  ...
# 464                  1243   38        F            B  ...
# 78561                1494   35        F            H  ...
# 14960                1107   16        M            H  ...
# 41221                1184   24        M            W  ...
# 78252                 706   28        M            H  ...
# 95343                 645   36        F            B  ...
# 48048                1381   27        M            H  ...
# 25766                1215   29        M            H  ...
# 55919                 985   48        M            W  ...
# 61898                 265   62        M            H  ...
# 10088                 666   49        F            W  ...
# 37681                1235   26        M            B  ...
# 72060                 853   63        M            H  ...
# 97044                1983   35        M            H  ...
# 81560                 901   61        M            W  ...
# 89947                 305   20        F            H  ...
