# %% [markdown]
# # 4/1(Mon) presentaion preparation

# %% [markdown]
# I used dispensaries/land area by zip code to calculate dispensaries "density" for plots.
#  no conclusion so far...
#
# * let me see how I can do stats more than just linear.
# ANOVA the number of dispensaries by zipcode

# %%
# Dependencies
from census import Census
from us import states
from config import (census_key, gkey)

import gmaps
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import json
import time

# %% [markdown]
# # Census Data Retrieval

# %%
# Census API Key
c = Census(census_key, year=2017)
    # for labels, https://api.census.gov/data/2017/acs/acs5/groups.html
census_data = c.acs5.get(("NAME",
                          "B01003_001E", #Population
                          "B01002_001E", #Median Age
                          "B19013_001E", #Household Income
                          "B19301_001E", #Per Capita Income
                          "B17001_002E", #Poverty Count"
                          "B23025_005E"  #Unemployment Count
                         ), 
                         {'for': 'zip code tabulation area:*'}) #by all'zip code:*'

# Convert to DataFrame
census_df = pd.DataFrame(census_data)

# Column Reordering
census_df = census_df.rename(columns={"NAME": "Name",
                                      "B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "B23025_005E": "Unemployment Count",
                                      "zip code tabulation area": "Zipcode"})

# Add in Poverty Rate (Poverty Count / Population)
census_df["Poverty Rate"] = 100 * census_df["Poverty Count"].astype(int) / census_df["Population"].astype(int)

# Add in unemployment Rate (Employment Count / Population)
census_df["Unemployment Rate"] = 100 * census_df["Unemployment Count"].astype(int) / census_df["Population"].astype(int)

# Final DataFrame
census_df = census_df[["Name","Zipcode","Population","Median Age","Household Income",
                       "Per Capita Income","Poverty Rate","Unemployment Rate"]]

# Visualize
print(len(census_df))
census_df.head()
# Out:
# 33120
#           Name Zipcode  Population  Median Age  Household Income  \
# 0  ZCTA5 00601   00601     17599.0        38.9           11757.0
# 1  ZCTA5 00602   00602     39209.0        40.9           16190.0
# 2  ZCTA5 00603   00603     50135.0        40.4           16645.0
# 3  ZCTA5 00606   00606      6304.0        42.8           13387.0
# 4  ZCTA5 00610   00610     27590.0        41.4           18741.0
#
#    Per Capita Income  Poverty Rate  Unemployment Rate
# 0             7041.0     64.105915          13.943974
# 1             8978.0     52.100283           6.473004
# 2            10897.0     50.216416           7.156677
# 3             5960.0     64.911168           3.236041
# 4             9266.0     45.498369           5.342515

# %%
census_df['Zipcode']=census_df['Zipcode'].astype(int)
census_df.to_csv("census.csv", encoding="utf-8", index=False)
census_df.dtypes
# Out:
# Name                  object
# Zipcode                int32
# Population           float64
# Median Age           float64
# Household Income     float64
# Per Capita Income    float64
# Poverty Rate         float64
# Unemployment Rate    float64
# dtype: object

# %% [markdown]
# # merge census and zip code coordinates

# %%
# load coordinates of zipcode
us_zip_coords=pd.read_csv('2018_Gaz_zcta_national.csv')

census_w_coords=pd.merge(census_df,us_zip_coords, left_on='Zipcode', right_on='GEOID')
print(len(census_w_coords))

del census_w_coords['GEOID']
census_w_coords.rename(columns={'ALAND':'Land Area (square meters)',
                        'AWATER':'Water Area (square meters)',
                        'ALAND_SQMI':'Land Area (square miles)',
                        'AWATER_SQMI':'Water Area (square miles)',
                        'INTPTLAT': 'Lat',
                        'INTPTLONG':'Lng'},inplace=True)
census_w_coords.head()
# Out:
# 33120
#           Name  Zipcode  Population  Median Age  Household Income  \
# 0  ZCTA5 00601      601     17599.0        38.9           11757.0
# 1  ZCTA5 00602      602     39209.0        40.9           16190.0
# 2  ZCTA5 00603      603     50135.0        40.4           16645.0
# 3  ZCTA5 00606      606      6304.0        42.8           13387.0
# 4  ZCTA5 00610      610     27590.0        41.4           18741.0
#
#    Per Capita Income  Poverty Rate  Unemployment Rate  \
# 0             7041.0     64.105915          13.943974
# 1             8978.0     52.100283           6.473004
# 2            10897.0     50.216416           7.156677
# 3             5960.0     64.911168           3.236041
# 4             9266.0     45.498369           5.342515
#
#    Land Area (square meters)  Water Area (square meters)  \
# 0                  166659749                      799292
# 1                   79307535                     4428429
# 2                   81887185                      181411
# 3                  109579993                       12487
# 4                   93013427                     4172059
#
#    Land Area (square miles)  Water Area (square miles)        Lat        Lng
# 0                    64.348                      0.309  18.180555 -66.749961
# 1                    30.621                      1.710  18.361945 -67.175597
# 2                    31.617                      0.070  18.455183 -67.119887
# 3                    42.309                      0.005  18.158327 -66.932928
# 4                    35.913                      1.611  18.295366 -67.125135

# %% [markdown]
# # Merge : LA county's zip codes + census w/coords(2017)

# %%
# load LA county's zip codes.csv
LA_county_zipcodes= pd.read_csv('LA_county_zipcodes.csv', dtype=object,encoding='utf8')
print(LA_county_zipcodes.head())
print(LA_county_zipcodes.dtypes)
LA_county_zipcodes['zipcode']=LA_county_zipcodes['zipcode'].astype(int)

#Filter only LA county's data from census by merging
LA_county=pd.merge(LA_county_zipcodes,census_w_coords,how='left',left_on='zipcode',right_on='Zipcode')
del LA_county['Classification']
del LA_county['Population_x']
del LA_county['Timezone']
del LA_county['Zipcode']
#LA_county['zipcode']=LA_county['zipcode'].astype(int)
print(LA_county.dtypes)
print(len(LA_county))
LA_county.head()
# Out:
#   zipcode Classification         City Population Timezone         Area Code(s)
# 0   90001        General  Los Angeles     57,110  Pacific                  323
# 1   90002        General  Los Angeles     51,223  Pacific              323/562
# 2   90003        General  Los Angeles     66,266  Pacific                  323
# 3   90004        General  Los Angeles     62,180  Pacific              323/213
# 4   90005        General  Los Angeles     37,681  Pacific  323/213/310/818/626
# zipcode           object
# Classification    object
# City              object
# Population        object
# Timezone          object
# Area Code(s)      object
# dtype: object
# zipcode                         int32
# City                           object
# Area Code(s)                   object
# Name                           object
# Population_y                  float64
# Median Age                    float64
# Household Income              float64
# Per Capita Income             float64
# Poverty Rate                  float64
# Unemployment Rate             float64
# Land Area (square meters)       int64
# Water Area (square meters)      int64
# Land Area (square miles)      float64
# Water Area (square miles)     float64
# Lat                           float64
# Lng                           float64
# dtype: object
# 282
#    zipcode         City         Area Code(s)         Name  Population_y  \
# 0    90001  Los Angeles                  323  ZCTA5 90001       58738.0
# 1    90002  Los Angeles              323/562  ZCTA5 90002       52856.0
# 2    90003  Los Angeles                  323  ZCTA5 90003       70490.0
# 3    90004  Los Angeles              323/213  ZCTA5 90004       62733.0
# 4    90005  Los Angeles  323/213/310/818/626  ZCTA5 90005       39562.0
#
#    Median Age  Household Income  Per Capita Income  Poverty Rate  \
# 0        28.7           35660.0            11882.0     31.757976
# 1        27.7           34000.0            11807.0     33.666944
# 2        28.2           34397.0            11305.0     32.929494
# 3        35.1           46581.0            30590.0     19.104777
# 4        35.4           32461.0            21566.0     28.562762
#
#    Unemployment Rate  Land Area (square meters)  Water Area (square meters)  \
# 0           4.974633                    9071081                           0
# 1           5.032541                    7930602                           0
# 2           5.440488                    9197637                         403
# 3           4.182806                    7894527                           0
# 4           5.156463                    2807558                           0
#
#    Land Area (square miles)  Water Area (square miles)        Lat         Lng
# 0                     3.502                        0.0  33.974026 -118.249510
# 1                     3.062                        0.0  33.949099 -118.246737
# 2                     3.551                        0.0  33.964131 -118.272783
# 3                     3.048                        0.0  34.076198 -118.310722
# 4                     1.084                        0.0  34.059163 -118.306892

# %% [markdown]
# ## Marijuana Dispensaries

# %%
marijuana_df=pd.read_csv('CannabisLicData_cleaned.csv')
marijuana_df.head()
# Out:
#         License Number                           License Type  \
# 0      C10-0000010-LIC            Cannabis - Retailer License
# 1      C10-0000009-LIC            Cannabis - Retailer License
# 2  C10-18-0000287-TEMP  Cannabis - Retailer Temporary License
# 3  C10-18-0000288-TEMP  Cannabis - Retailer Temporary License
# 4  C10-18-0000289-TEMP  Cannabis - Retailer Temporary License
#
#                              Business Owner  \
# 0              KAREN KISSLER: KAREN KISSLER
# 1  John Swanston: John Swanston: Sean Eaddy
# 2                           Angel Fernandez
# 3                              Basil Bailey
# 4                           Michael O'Leary
#
#                         Business Contact Information Business Structure  \
# 0  ALTERNATIVES, A HEALTH COLLECTIVE  : ALTERNATI...        Corporation
# 1  HORIZON NONPROFIT COLLECTIVE : Email- horizonc...                NaN
# 2  MOVOCAN : Email- medigroupangel@gmail.com : Ph...        Corporation
# 3  ORIGINAL BALBOA CAREGIVERS : Email- balboacare...        Corporation
# 4  Medallion Wellness, Inc. : Email- michael@meda...        Corporation
#
#                  Premise Address  CA  Zip Code County_with leading space  \
# 0    1603 HAMPTON WAY SANTA ROSA  CA     95407                   SONOMA
# 1  1841 EL CAMINO AVE SACRAMENTO  CA     95815               SACRAMENTO
# 2       1632 GATEWAY RD CALEXICO  CA     92231                  IMPERIAL
# 3      9419 MASON AVE CHATSWORTH  CA     91311              LOS ANGELES
# 4      341 Business PKWY Atwater  CA     95301
#
#         County  Status  Issue Date Expiration Date                 Activities  \
# 0       SONOMA  Active   3/19/2019       3/18/2020  N/A for this license type
# 1   SACRAMENTO  Active   1/31/2019       1/31/2020  N/A for this license type
# 2     IMPERIAL  Active  12/31/2018       7/29/2019  N/A for this license type
# 3  LOS ANGELES  Active  12/31/2018       7/29/2019  N/A for this license type
# 4          NaN  Active  12/31/2018       7/29/2019  N/A for this license type
#
#   Adult-Use/Medicinal
# 0                BOTH
# 1                BOTH
# 2           Medicinal
# 3                BOTH
# 4                BOTH

# %%
# count the number of dispensaries in each zipcode
marijuana_zip=marijuana_df['Zip Code'].value_counts()
# sort by index (zipcode)
marijuana_zip.sort_index(inplace=True)
# convert a series to a dataframe
marijuana_zip_df=pd.DataFrame(marijuana_zip)#columns='zipcode'
marijuana_zip_df.reset_index(inplace=True)
marijuana_zip_df=marijuana_zip_df.rename(columns={'index':'zipcode','Zip Code':'Count'})
marijuana_zip_df.dtypes
print(len(marijuana_zip_df))
marijuana_zip_df.head()
# Out:
# Index(['License Number', 'License Type', 'Business Owner',
#        'Business Contact Information', 'Business Structure', 'Premise Address',
#        'CA', 'Zip Code', 'County_with leading space', 'County', 'Status',
#        'Issue Date', 'Expiration Date', 'Activities', 'Adult-Use/Medicinal',
#        'Latitude', 'Longitude'],
#       dtype='object')
# 263
#    zipcode  Count
# 0    90001      3
# 1    90007      1
# 2    90008      1
# 3    90012      1
# 4    90014      1

# %% [markdown]
# ## Merge : LA county zipcode&census + #of marijuana dispensaries

# %%
N_marijuana_by_zipcode=pd.merge(LA_county,marijuana_zip_df, how='left', on='zipcode')

print(N_marijuana_by_zipcode.head())
print(len(N_marijuana_by_zipcode))
print(N_marijuana_by_zipcode['Count'].dtypes)

#convert NaN to 0 in 'Count'column
N_marijuana_by_zipcode['Count']=N_marijuana_by_zipcode['Count'].fillna(0)
N_marijuana_by_zipcode['Count'].value_counts()

#calculate count/land area
N_marijuana_by_zipcode['disps_density']=N_marijuana_by_zipcode['Count']/N_marijuana_by_zipcode['Land Area (square miles)']
N_marijuana_by_zipcode.head()
# Out:
#    zipcode         City         Area Code(s)         Name  Population_y  \
# 0    90001  Los Angeles                  323  ZCTA5 90001       58738.0
# 1    90002  Los Angeles              323/562  ZCTA5 90002       52856.0
# 2    90003  Los Angeles                  323  ZCTA5 90003       70490.0
# 3    90004  Los Angeles              323/213  ZCTA5 90004       62733.0
# 4    90005  Los Angeles  323/213/310/818/626  ZCTA5 90005       39562.0
#
#    Median Age  Household Income  Per Capita Income  Poverty Rate  \
# 0        28.7           35660.0            11882.0     31.757976
# 1        27.7           34000.0            11807.0     33.666944
# 2        28.2           34397.0            11305.0     32.929494
# 3        35.1           46581.0            30590.0     19.104777
# 4        35.4           32461.0            21566.0     28.562762
#
#    Unemployment Rate  Land Area (square meters)  Water Area (square meters)  \
# 0           4.974633                    9071081                           0
# 1           5.032541                    7930602                           0
# 2           5.440488                    9197637                         403
# 3           4.182806                    7894527                           0
# 4           5.156463                    2807558                           0
#
#    Land Area (square miles)  Water Area (square miles)        Lat         Lng  \
# 0                     3.502                        0.0  33.974026 -118.249510
# 1                     3.062                        0.0  33.949099 -118.246737
# 2                     3.551                        0.0  33.964131 -118.272783
# 3                     3.048                        0.0  34.076198 -118.310722
# 4                     1.084                        0.0  34.059163 -118.306892
#
#    Count
# 0    3.0
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 282
# float64
#    zipcode         City         Area Code(s)         Name  Population_y  \
# 0    90001  Los Angeles                  323  ZCTA5 90001       58738.0
# 1    90002  Los Angeles              323/562  ZCTA5 90002       52856.0
# 2    90003  Los Angeles                  323  ZCTA5 90003       70490.0
# 3    90004  Los Angeles              323/213  ZCTA5 90004       62733.0
# 4    90005  Los Angeles  323/213/310/818/626  ZCTA5 90005       39562.0
#
#    Median Age  Household Income  Per Capita Income  Poverty Rate  \
# 0        28.7           35660.0            11882.0     31.757976
# 1        27.7           34000.0            11807.0     33.666944
# 2        28.2           34397.0            11305.0     32.929494
# 3        35.1           46581.0            30590.0     19.104777
# 4        35.4           32461.0            21566.0     28.562762
#
#    Unemployment Rate  Land Area (square meters)  Water Area (square meters)  \
# 0           4.974633                    9071081                           0
# 1           5.032541                    7930602                           0
# 2           5.440488                    9197637                         403
# 3           4.182806                    7894527                           0
# 4           5.156463                    2807558                           0
#
#    Land Area (square miles)  Water Area (square miles)        Lat         Lng  \
# 0                     3.502                        0.0  33.974026 -118.249510
# 1                     3.062                        0.0  33.949099 -118.246737
# 2                     3.551                        0.0  33.964131 -118.272783
# 3                     3.048                        0.0  34.076198 -118.310722
# 4                     1.084                        0.0  34.059163 -118.306892
#
#    Count  disps_density
# 0    3.0       0.856653
# 1    0.0       0.000000
# 2    0.0       0.000000
# 3    0.0       0.000000
# 4    0.0       0.000000

# %%
N_marijuana_by_zipcode.plot.scatter('Poverty Rate','Count',color='b' )
plt.grid()

# %%
N_marijuana_by_zipcode.plot.scatter('Poverty Rate','disps_density',color='g' )
plt.grid()

# %%
N_marijuana_by_zipcode.plot.scatter('Unemployment Rate','disps_density', color='r' )
plt.grid()

# %% [markdown]
# # Google call for coordinates of dispensaries

# %%
# set up additional columns to hold information
marijuana_df['Latitude']=''
marijuana_df['Longitude']=''
marijuana_df.head()

# %%
# test
# address='1603 HAMPTON WAY SANTA ROSA'
# target_url=('https://maps.googleapis.com/maps/api/geocode/json?''address={0}&key={1}').format(address,gkey)
# mari_coords=requests.get(target_url).json()
# print(json.dumps(mari_coords, indent=4, sort_keys=True))
# mari_coords["results"][0]["geometry"]["location"]["lat"]

# %%
for index, row in marijuana_df.iterrows():
    address=row['Premise Address']
    target_url=('https://maps.googleapis.com/maps/api/geocode/json?''address={0}&key={1}').format(address,gkey)
    mari_coords=requests.get(target_url).json()
    try:
        marijuana_df.loc[index,'Latitude'] = mari_coords["results"][0]["geometry"]["location"]["lat"]
        marijuana_df.loc[index,'Longitude'] = mari_coords["results"][0]["geometry"]["location"]["lng"]
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
marijuana_df.head()
# Out:
#         License Number                           License Type  \
# 0      C10-0000010-LIC            Cannabis - Retailer License
# 1      C10-0000009-LIC            Cannabis - Retailer License
# 2  C10-18-0000287-TEMP  Cannabis - Retailer Temporary License
# 3  C10-18-0000288-TEMP  Cannabis - Retailer Temporary License
# 4  C10-18-0000289-TEMP  Cannabis - Retailer Temporary License
#
#                              Business Owner  \
# 0              KAREN KISSLER: KAREN KISSLER
# 1  John Swanston: John Swanston: Sean Eaddy
# 2                           Angel Fernandez
# 3                              Basil Bailey
# 4                           Michael O'Leary
#
#                         Business Contact Information Business Structure  \
# 0  ALTERNATIVES, A HEALTH COLLECTIVE  : ALTERNATI...        Corporation
# 1  HORIZON NONPROFIT COLLECTIVE : Email- horizonc...                NaN
# 2  MOVOCAN : Email- medigroupangel@gmail.com : Ph...        Corporation
# 3  ORIGINAL BALBOA CAREGIVERS : Email- balboacare...        Corporation
# 4  Medallion Wellness, Inc. : Email- michael@meda...        Corporation
#
#                  Premise Address  CA  Zip Code County_with leading space  \
# 0    1603 HAMPTON WAY SANTA ROSA  CA     95407                   SONOMA
# 1  1841 EL CAMINO AVE SACRAMENTO  CA     95815               SACRAMENTO
# 2       1632 GATEWAY RD CALEXICO  CA     92231                  IMPERIAL
# 3      9419 MASON AVE CHATSWORTH  CA     91311              LOS ANGELES
# 4      341 Business PKWY Atwater  CA     95301
#
#         County  Status  Issue Date Expiration Date                 Activities  \
# 0       SONOMA  Active   3/19/2019       3/18/2020  N/A for this license type
# 1   SACRAMENTO  Active   1/31/2019       1/31/2020  N/A for this license type
# 2     IMPERIAL  Active  12/31/2018       7/29/2019  N/A for this license type
# 3  LOS ANGELES  Active  12/31/2018       7/29/2019  N/A for this license type
# 4          NaN  Active  12/31/2018       7/29/2019  N/A for this license type
#
#   Adult-Use/Medicinal Latitude Longitude
# 0                BOTH  38.4283  -122.738
# 1                BOTH  38.6115  -121.423
# 2           Medicinal  32.6892  -115.389
# 3                BOTH  34.2413  -118.581
# 4                BOTH  37.3477  -120.609

# %%
marijuana_df.to_csv('marijuana_dispensaries_w_coords.csv')

# %%
# Access maps with unique API key
gmaps.configure(api_key=gkey)

# use symbol layer to pinpoint the locations of dispensaries
mari_disp_symbol=marijuana_df[['Latitude','Longitude']]
mari_disp_layer=gmaps.symbol_layer(
                mari_disp_symbol, 
                fill_color='rgba(0, 90, 0, 0.4)',
                stroke_color='rgba(0, 150, 0, 0.4)', 
                scale=2 )
fig = gmaps.figure()
fig.add_layer(mari_disp_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
N_marijuana_by_zipcode['Unemployment Rate'].describe()
# Out:
# count    281.000000
# mean       3.935512
# std        1.418547
# min        0.000000
# 25%        3.063882
# 50%        3.835923
# 75%        4.824001
# max       13.369631
# Name: Unemployment Rate, dtype: float64

# %%
#Heatmap
# Store latitude and longitude in locations
locations=N_marijuana_by_zipcode[['Lat','Lng']]

# weight as unemployment
unemployment=N_marijuana_by_zipcode['Unemployment Rate']


fig=gmaps.figure()
# layter
heat_layer=gmaps.heatmap_layer(locations, weights=unemployment, 
                               max_intensity=5,point_radius =8
                                 )
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
fig=gmaps.figure()
fig.add_layer(mari_disp_layer)
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
